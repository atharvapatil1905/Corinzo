# %% [markdown]
# ## CAPSTONE PROJECT 2

# %% [markdown]
# We will build a classifier to predict the Pass/Fail yield of a
# particular process entity and analyse whether all the features are required to build the
# model or not

# %% [markdown]
# Importing Modules

# %%
import pandas as pd

# %% [markdown]
# Data Connection

# %%
df = pd.read_csv(
    r"C:\Users\hp\repositories\Corizo\Corinzo\Data Science\Jupyter\Project\Major\signal-data.csv"
)

# %%
df.head()
# Out:
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...       581     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...       NaN  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  208.2045  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   82.8602  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   73.8432  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...       NaN  0.4800  0.4766  0.1045  99.3032
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Columns: 592 entries, Time to Pass/Fail
# dtypes: float64(590), int64(1), object(1)
# memory usage: 7.1+ MB

# %%
df.describe()
# Out:
#                  0            1            2            3            4  \
# count  1561.000000  1560.000000  1553.000000  1553.000000  1553.000000
# mean   3014.452896  2495.850231  2200.547318  1396.376627     4.197013
# std      73.621787    80.407705    29.513152   441.691640    56.355540
# min    2743.240000  2158.750000  2060.660000     0.000000     0.681500
# 25%    2966.260000  2452.247500  2181.044400  1081.875800     1.017700
# 50%    3011.490000  2499.405000  2201.066700  1285.214400     1.316800
# 75%    3056.650000  2538.822500  2218.055500  1591.223500     1.525700
# max    3356.350000  2846.440000  2315.266700  3715.041700  1114.536600
#
#             5            6            7            8            9  ...  \
# count  1553.0  1553.000000  1558.000000  1565.000000  1565.000000  ...
# mean    100.0   101.112908     0.121822     1.462862    -0.000841  ...
# std       0.0     6.237214     0.008961     0.073897     0.015116  ...
# ...

# %%
df.isnull()
# Out:
#        Time      0      1      2      3      4      5      6      7      8  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1562  False  False  False  False  False  False  False  False  False  False
# 1563  False  False  False  False  False  False  False  False  False  False
# 1564  False  False  False  False  False  False  False  False  False   True
# 1565  False  False  False  False  False  False  False  False  False  False
# 1566  False  False  False  False  False  False  False  False  False   True
#
# ...

# %%
df.isnull().sum()
# Out:
# Time          0
# 0             6
# 1             7
# 2            14
# 3            14
#              ..
# 586           1
# 587           1
# 588           1
# 589           1
# Pass/Fail     0
# Length: 592, dtype: int64

# %% [markdown]
# Insights from CSV
#
# 1.Rows (Samples): 1,567
#
# 2.Columns (Features): 592
#
# 3.Data Types
#
#     i.float64: 590 columns (mostly signal measurements)
#
#     ii.int64: 1 column (Pass/Fail)
#
#     iii.object: 1 column (Time)
#
# 4.Column Highlight
#
#     i.Time: Timestamp of when the signal was recorded (string format)
#
#     ii.0 to 589: These columns likely represent signal features extracted from some system/device
#
#     iii.Pass/Fail: Target variable indicating -1 (Fail) or 1 (Pass)
#
# 5.Contains Multiple null/empty cells
#
# 6.NO DUPLICATES rows were found in the dataset. EACH ROW IS UNIQUE
