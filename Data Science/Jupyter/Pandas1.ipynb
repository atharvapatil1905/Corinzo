# %% [markdown]
# ### Import Numpy and Pandas Libraries

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Q1. Read the '.csv' file into a data frame and display the first 5 rows.

# %%
df1 = pd.read_csv('/content/drive/My Drive/AIML Mentoring/Practice/Forbes_Billionaire.csv')
print(df1.shape)
df1.head()
# Out:
# (2095, 7)
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df1.tail(10)
# Out:
#       Rank                    Name   Age  Net Worth        Country  \
# 2085  1990             SANDY WEILL  87.0        1.0  United States
# 2086  1990      LI XIANYU & FAMILY  66.0        1.0          China
# 2087  1990             MORRIS KAHN  90.0        1.0         Israel
# 2088  1990  CHANCHAI RUAYRUNGRUANG  66.0        1.0          China
# 2089  1990             JIN HUIMING  67.0        1.0          China
# 2090  1990              DAVID HALL  68.0        1.0  United States
# 2091  1990                  DU SHA  73.0        1.0          China
# 2092  1990            WANG YANQING  73.0        1.0          China
# 2093  1990               XU WANMAO  75.0        1.0          China
# 2094  1990           WANG MIAOTONG  62.0        1.0          China
#
#                      Source             Industries
# 2085              Citigroup  Finance & Investments
# 2086        pharmaceuticals             Healthcare
# 2087               software             Technology
# ...

# %% [markdown]
# # Q2. Name the top 8 industries with maximum count of billionaires

# %%
ind_list_asc = df1['Industries'].value_counts().head(8).index.to_list()
ind_list_asc
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %%
df1.head()
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df1['Industries'].value_counts().head(8).index.to_list()
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %%
df1.groupby('Industries')['Country'].count().sort_values(ascending=False)
# .count().sort_values(ascending=False).head(8).index.to_list()
# df2.head(10)
# df2.iloc[0:8].index.to_list()
# df2.head(8)
# Out:
# Industries
# Finance & Investments         298
# Technology                    241
# Fashion & Retail              209
# Manufacturing                 198
# Real Estate                   196
# Diversified                   169
# Food & Beverage               168
# Healthcare                    149
# Energy                         80
# Media & Entertainment          74
# Service                        65
# Metals & Mining                59
# Automotive                     47
# Construction & Engineering     35
# Logistics                      33
# Telecom                        29
# Sports                         24
# Gambling & Casinos             21
# Name: Country, dtype: int64

# %%
df1['Industries'].value_counts().index.to_list()[0:8]
# l1[0:8]
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %%
ind_list_asc = df1['Industries'].value_counts().reset_index().head(8)['Industries'].to_list()
ind_list_asc
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %% [markdown]
# # Q3. State the headcount of billionaires from these top 8 industries

# %%
df1['Industries'].value_counts().reset_index(drop=False)['count'].head(8).to_list()
# .head(8)['count'].to_list()
# ['count'].to_list()
# Out:
# [298, 241, 209, 198, 196, 169, 168, 149]

# %%
ind_list_asc[0:8]
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %%
df1.head(15)
# Out:
#     Rank                                   Name   Age  Net Worth  \
# 0      1                             JEFF BEZOS  56.0      113.0
# 1      2                             BILL GATES  64.0       98.0
# 2      3               BERNARD ARNAULT & FAMILY  71.0       76.0
# 3      4                         WARREN BUFFETT  89.0       67.5
# 4      5                          LARRY ELLISON  75.0       59.0
# 5      6                         AMANCIO ORTEGA  84.0       55.1
# 6      7                        MARK ZUCKERBERG  35.0       54.7
# 7      8                             JIM WALTON  71.0       54.6
# 8      9                           ALICE WALTON  70.0       54.4
# 9     10                             ROB WALTON  75.0       54.1
# 10    11                          STEVE BALLMER  64.0       52.7
# 11    12              CARLOS SLIM HELU & FAMILY  80.0       52.1
# 12    13                             LARRY PAGE  47.0       50.9
# ...

# %% [markdown]
# # Q4. Compare the mean of net worth of billionaires from these top 8 industries.

# %%
ind_list_asc
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare']

# %%
df1.head()
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df1[df1['Industries'].isin(ind_list_asc)]
# Out:
#       Rank                      Name   Age  Net Worth        Country  \
# 0        1                JEFF BEZOS  56.0      113.0  United States
# 1        2                BILL GATES  64.0       98.0  United States
# 2        3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3        4            WARREN BUFFETT  89.0       67.5  United States
# 4        5             LARRY ELLISON  75.0       59.0  United States
# ...    ...                       ...   ...        ...            ...
# 2087  1990               MORRIS KAHN  90.0        1.0         Israel
# 2088  1990    CHANCHAI RUAYRUNGRUANG  66.0        1.0          China
# 2089  1990               JIN HUIMING  67.0        1.0          China
# 2091  1990                    DU SHA  73.0        1.0          China
# 2092  1990              WANG YANQING  73.0        1.0          China
#
#                      Source             Industries
# 0                    Amazon             Technology
# ...

# %%
df33 = df1[df1['Industries'].isin(ind_list_asc)]
df33
# Out:
#       Rank                      Name   Age  Net Worth        Country  \
# 0        1                JEFF BEZOS  56.0      113.0  United States
# 1        2                BILL GATES  64.0       98.0  United States
# 2        3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3        4            WARREN BUFFETT  89.0       67.5  United States
# 4        5             LARRY ELLISON  75.0       59.0  United States
# ...    ...                       ...   ...        ...            ...
# 2087  1990               MORRIS KAHN  90.0        1.0         Israel
# 2088  1990    CHANCHAI RUAYRUNGRUANG  66.0        1.0          China
# 2089  1990               JIN HUIMING  67.0        1.0          China
# 2091  1990                    DU SHA  73.0        1.0          China
# 2092  1990              WANG YANQING  73.0        1.0          China
#
#                      Source             Industries
# 0                    Amazon             Technology
# ...

# %%
df3 = df33.groupby('Industries')['Net Worth'].mean().reset_index().sort_values(by='Net Worth', ascending=False)
# df3.sort_values(by='Net Worth', ascending=False, inplace=True)
# df4 = df3.sort_values(by='Net Worth', ascending=False)

df3.head(8)
# Out:
#               Industries  Net Worth
# 7             Technology   5.634440
# 1       Fashion & Retail   5.372727
# 3        Food & Beverage   3.708333
# 2  Finance & Investments   3.430201
# 0            Diversified   3.293491
# 6            Real Estate   3.277551
# 4             Healthcare   2.857047
# 5          Manufacturing   2.730303

# %% [markdown]
# # Q5. Compare the mean age of billionaires from these top 8 industries.

# %%
df33 = df1[df1['Industries'].isin(ind_list_asc[0:8])]
df4 = df33.groupby('Industries')['Age'].mean().reset_index()
df4.head(10)
# Out:
#               Industries        Age
# 0            Diversified  66.889571
# 1       Fashion & Retail  66.893204
# 2  Finance & Investments  65.810811
# 3        Food & Beverage  64.862500
# 4             Healthcare  63.088435
# 5          Manufacturing  64.139896
# 6            Real Estate  65.895288
# 7             Technology  55.375527

# %%
df1.head()
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %% [markdown]
# # Q6. Name the Richest billionaire in the Automotive sector

# %%
df1[df1['Industries']=='Automotive'].sort_values(by='Net Worth', ascending=False).head(1)['Name']
# Out:
# 30    ELON MUSK
# Name: Name, dtype: object

# %%
df1.head(5)
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df1.head(10)
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
# 5     6            AMANCIO ORTEGA  84.0       55.1          Spain
# 6     7           MARK ZUCKERBERG  35.0       54.7  United States
# 7     8                JIM WALTON  71.0       54.6  United States
# 8     9              ALICE WALTON  70.0       54.4  United States
# 9    10                ROB WALTON  75.0       54.1  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# ...

# %% [markdown]
# # Q7. Name top 5 countries with maximum number of billionaires.

# %%
df1['Country'].value_counts().head(5).index.to_list()

# df6 = df1['Country'].value_counts().reset_index()
# df6.head(5)
# Out:
# ['United States', 'China', 'Germany', 'India', 'Russia']

# %%
l1 = df1.groupby('Country')['Industries'].count().sort_values(ascending=False).head(5).index.to_list()
l1
# Out:
# ['United States', 'China', 'Germany', 'India', 'Russia']

# %% [markdown]
# # Q8. Which amongst these top 5 countries have the lowest mean age of billionaires ?

# %%
df88 = df1[df1['Country'].isin(l1)]
df88.groupby('Country')['Age'].mean().sort_values(ascending=True).reset_index()['Country'][0]
# Out:
# 'China'

# %%
list1 = df1['Country'].value_counts().index.to_list()
list_main = list1[0:5]
list_main
# Out:
# ['United States', 'China', 'Germany', 'India', 'Russia']

# %%
df1[df1['Country'].isin(list_main)].groupby('Country')['Age'].mean().sort_values(ascending=True)
# Out:
# Country
# China            56.790026
# Russia           56.848485
# Germany          64.147368
# India            66.206186
# United States    66.911620
# Name: Age, dtype: float64

# %%
df1.head()
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %% [markdown]
# # Q9. Name the richest Chinese billionaire and his net worth

# %%
df1[df1['Country']=='China'].sort_values(by='Net Worth', ascending=False).head(1)['Name']
# .sort_values(by='Net Worth', ascending=False).head(1)['Name']
# .head(1)
# Out:
# 16    JACK MA
# Name: Name, dtype: object

# %%
df1[df1['Country']=='India'].groupby('Industries')['Source'].count().sort_values(ascending=False)
#  ['Industries'].value_counts().head(5).index.to_list()
# Out:
# Industries
# Healthcare                    17
# Manufacturing                 14
# Diversified                   13
# Technology                    11
# Food & Beverage                8
# Real Estate                    8
# Automotive                     6
# Fashion & Retail               6
# Construction & Engineering     4
# Finance & Investments          4
# Service                        4
# Metals & Mining                3
# Energy                         2
# Media & Entertainment          1
# Telecom                        1
# Name: Source, dtype: int64

# %% [markdown]
# # Q10. Name top 5 Industries with maximum number of Indian billionaires.

# %%
df1[df1['Country']=='India']['Industries'].value_counts().head(5)
# Out:
# Industries
# Healthcare         17
# Manufacturing      14
# Diversified        13
# Technology         11
# Food & Beverage     8
# Name: count, dtype: int64

# %% [markdown]
# # Q11. Name all the Indian billionaires in global top 100 list.

# %%
df10 = df1.sort_values(by='Net Worth', ascending=False).reset_index(drop=True).iloc[0:100, :]
df10[df10['Country']=='India'].head(10)
# Out:
#     Rank                         Name   Age  Net Worth Country  \
# 20    21                MUKESH AMBANI  62.0       36.8   India
# 77    78  RADHAKISHAN DAMANI & FAMILY  65.0       13.8   India
#
#                        Source        Industries
# 20  petrochemicals, oil & gas            Energy
# 77        retail, investments  Fashion & Retail

# %% [markdown]
# # Q12. Name all the billionaires in India who are younger than 50 years. Also state their mean net worth

# %%
df12 = df1[(df1['Country']=='India') & (df1['Age']<50)]
df12.head(10)
# Out:
#       Rank                  Name   Age  Net Worth Country  \
# 874    875  VIJAY SHEKHAR SHARMA  41.0        2.4   India
# 1196  1196       BYJU RAVEENDRAN  38.0        1.8   India
# 1237  1196          VIKAS OBEROI  49.0        1.8   India
# 1420  1415            RANJAN PAI  47.0        1.5   India
# 1618  1613     SHAMSHEER VAYALIL  43.0        1.3   India
# 1732  1730         SACHIN BANSAL  38.0        1.2   India
# 1742  1730           RADHA VEMBU  47.0        1.2   India
# 1856  1851          BINNY BANSAL  37.0        1.1   India
# 1867  1851    ACHARYA BALKRISHNA  47.0        1.1   India
#
#                     Source        Industries
# 874   financial technology           Service
# 1196  education technology        Technology
# 1237           real estate       Real Estate
# 1420             education           Service
# 1618            healthcare        Healthcare
# 1732              flipkart  Fashion & Retail
# 1742            technology        Technology
# ...

# %%
df12['Net Worth'].mean()
# Out:
# 1.488888888888889

# %% [markdown]
# # Q13. Name the Indian billionaires from real estate sector who are richer than 'DONALD TRUMP'.

# %%
dtrump_worth = df1[df1['Name']=='DONALD TRUMP']['Net Worth'].reset_index(drop=True)[0]
dtrump_worth
# Out:
# 2.1

# %%
df1[(df1['Country']=='India') & (df1['Industries']=='Real Estate') & (df1['Net Worth']>dtrump_worth)]
# Out:
#      Rank              Name   Age  Net Worth Country       Source   Industries
# 494   494  KUSHAL PAL SINGH  88.0        3.7   India  real estate  Real Estate
# 774   764    CHANDRU RAHEJA  79.0        2.7   India  real estate  Real Estate

# %% [markdown]
# # Q14. What is the total cumulative net worth of all the billionaires?

# %%
df1['Net Worth'].sum()
# Out:
# 8037.499999999999
